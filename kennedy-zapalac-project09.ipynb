# %% [markdown]
# # Project 9 -- Kennedy Zapalac

# %% [markdown]
# **TA Help:** N/A
#
# **Collaboration:** N/A

# %%
# %sql sqlite:////anvil/projects/tdm/data/lahman/lahman.db

# %% [markdown]
# ## Question 1
#
# a. Write a query to find out who won the 2022 World Baseball Series from table `seriespost`?
#
# b. For this champion team, please find out the home runs (hr) rate and runs batted in (rbi) rate in year 2022 from table batting. Round the rates to 2 decimals. You may get rates by
#
#     - hr_rate = sum of home runs / sum of hits
#     - rbi_rate = sum of runs batted in / sum of hits

# %%
# %%sql
# SELECT * FROM seriespost WHERE yearID = 2022 AND round = 'WS';
# Out:
#  * sqlite:////anvil/projects/tdm/data/lahman/lahman.db
# Done.
# [(2022, 'WS', 'HOU', 'NL', 'PHI', 'NL', 4, 2, 0)]

# %%
# %%sql
# SELECT
#     ROUND(CAST(SUM(HR) AS REAL)/SUM(H), 2) AS hr_rate, # must cast at least one of the inputs as a real number so that the output is a decimal rather than 0
#     ROUND(CAST(SUM(RBI) AS REAL)/SUM(H), 2) AS rbi_rate
# FROM
#     batting
# WHERE
#     yearID = 2022 AND teamID = 'HOU';
# Out:
#  * sqlite:////anvil/projects/tdm/data/lahman/lahman.db
# Done.
# [(0.16, 0.53)]

# %% [markdown]
# The Houston team won the 2022 world series and had a home run rate of 0.16 and a runs batted in rate of 0.53.

# %% [markdown]
# ## Question 2
# a. For the champion team from question 1, please write a query that counts the number of RBIs for each athlete in the champion team during year 2022, using the `batting` table. Display your output in ascending order.
#
# b. Run the query again, but this time, display the output in descending order.
#
# c. Which athlete has the highest RBIs in this question? Please provide the player’s `playerID`, along with their first name and last name, from the `people` table

# %%
# %%sql
# SELECT
#     b.playerID,
#     p.nameFirst,
#     p.nameLast,
#     b.RBI
# FROM
#     batting AS b
# JOIN
#     people AS p
# ON
#     b.playerID = p.playerID
# WHERE
#     teamID = 'HOU' AND yearID = 2022
# ORDER BY
#     b.RBI ASC;
# Out:
#  * sqlite:////anvil/projects/tdm/data/lahman/lahman.db
# Done.
# [('abreubr01', 'Bryan', 'Abreu', 0),
#  ('baezpe01', 'Pedro', 'Baez', 0),
#  ('bielabr01', 'Brandon', 'Bielak', 0),
#  ('blancro01', 'Ronel', 'Blanco', 0),
#  ('brownhu01', 'Hunter', 'Brown', 0),
#  ('garcilu05', 'Luis', 'Garcia', 0),
#  ('javiecr01', 'Cristian', 'Javier', 0),
#  ('jonesta01', 'Taylor', 'Jones', 0),
#  ('martise01', 'Seth', 'Martinez', 0),
#  ('matonph01', 'Phil', 'Maton', 0),
#  ('mcculla02', 'Lance', 'McCullers', 0),
#  ('montera01', 'Rafael', 'Montero', 0),
#  ('mushipa01', 'Parker', 'Mushinski', 0),
#  ('nerishe01', 'Hector', 'Neris', 0),
#  ('odorija01', 'Jake', 'Odorizzi', 0),
#  ('pareden01', 'Enoli', 'Paredes', 0),
#  ('perezjo01', 'Joe', 'Perez', 0),
#  ('pressry01', 'Ryan', 'Pressly', 0),
#  ('smithwi04', 'Will', 'Smith', 0),
#  ('stanery01', 'Ryne', 'Stanek', 0),
#  ('taylobl01', 'Blake', 'Taylor', 0),
#  ('urquijo01', 'Jose', 'Urquidy', 0),
#  ('valdefr01', 'Framber', 'Valdez', 0),
# ...

# %%
# %%sql
# SELECT
#     b.playerID,
#     p.nameFirst,
#     p.nameLast,
#     b.RBI
# FROM
#     batting AS b
# JOIN
#     people AS p
# ON
#     b.playerID = p.playerID
# WHERE
#     teamID = 'HOU' AND yearID = 2022
# ORDER BY
#     b.RBI DESC;
# Out:
#  * sqlite:////anvil/projects/tdm/data/lahman/lahman.db
# Done.
# [('tuckeky01', 'Kyle', 'Tucker', 107),
#  ('alvaryo01', 'Yordan', 'Alvarez', 97),
#  ('bregmal01', 'Alex', 'Bregman', 93),
#  ('penaje02', 'Jeremy', 'Pena', 63),
#  ('altuvjo01', 'Jose', 'Altuve', 57),
#  ('gourryu01', 'Yuli', 'Gurriel', 53),
#  ('maldoma01', 'Martin', 'Maldonado', 45),
#  ('mccorch01', 'Chas', 'McCormick', 44),
#  ('diazal02', 'Aledmys', 'Diaz', 38),
#  ('brantmi02', 'Michael', 'Brantley', 26),
#  ('mancitr01', 'Trey', 'Mancini', 22),
#  ('dubonma01', 'Mauricio', 'Dubon', 16),
#  ('meyerja02', 'Jake', 'Meyers', 15),
#  ('sirijo01', 'Jose', 'Siri', 10),
#  ('vazquch01', 'Christian', 'Vazquez', 10),
#  ('henslda01', 'David', 'Hensley', 5),
#  ('matijjj01', 'J. J.', 'Matijevic', 5),
#  ('leeko01', 'Korey', 'Lee', 4),
#  ('castrja01', 'Jason', 'Castro', 3),
#  ('diazya02', 'Yainer', 'Diaz', 1),
#  ('goodrni01', 'Niko', 'Goodrum', 1),
#  ('abreubr01', 'Bryan', 'Abreu', 0),
# ...

# %%
# %%sql
# SELECT
#     b.playerID,
#     p.nameFirst,
#     p.nameLast,
#     b.RBI
# FROM
#     batting AS b
# JOIN
#     people AS p
# ON
#     b.playerID = p.playerID
# WHERE
#     teamID = 'HOU' AND yearID = 2022
# ORDER BY
#     b.RBI DESC
# LIMIT 1;
# Out:
#  * sqlite:////anvil/projects/tdm/data/lahman/lahman.db
# Done.
# [('tuckeky01', 'Kyle', 'Tucker', 107)]

# %% [markdown]
# Kyle Tucker had the greatest RBI of 107 of rthe Houston team in 2022. His player ID is tuckeky01.

# %% [markdown]
# ## Question 3
# a. Write a query that finds how many times the athlete from question 2 attended All Star Games.
#
# b. Write a query to find out who is the athlete that attended most All Star Games in the entire data set.

# %%
# %%sql
# SELECT COUNT(*) FROM allstarfull WHERE playerID = 'tuckeky01';
# Out:
#  * sqlite:////anvil/projects/tdm/data/lahman/lahman.db
# Done.
# [(1,)]

# %%
# %%sql
# SELECT
#     playerID,
#     COUNT(*) AS attendance
# FROM
#     allstarfull
# GROUP BY
#     playerID
# ORDER BY
#     attendance DESC
# LIMIT 1;
# Out:
#  * sqlite:////anvil/projects/tdm/data/lahman/lahman.db
# Done.
# [('mayswi01', 26)]

# %%
# %%sql
# SELECT
#     playerID,
#     nameFirst,
#     nameLast
# FROM
#     people
# WHERE
#     playerID = 'mayswi01';
# Out:
#  * sqlite:////anvil/projects/tdm/data/lahman/lahman.db
# Done.
# [('mayswi01', 'Willie', 'Mays')]

# %% [markdown]
# Kyle Tucker only appeared in 1 All Star Game. Willie Mays appeared in the most All Star Games in this dataset. He appeared 26 times.

# %% [markdown]
# ## Question 4
# a. Write a query that gets the average salary for each athlete in the database. Display your output in descending order. Limit the output to 100 rows (i.e., to the top 100 salaries).

# %%
# %%sql
# SELECT
#     playerID,
#     AVG(salary) as avg_salary
# FROM
#     salaries
# GROUP BY
#     playerID
# ORDER BY
#     avg_salary DESC
# LIMIT 100;
# Out:
#  * sqlite:////anvil/projects/tdm/data/lahman/lahman.db
# Done.
# [('tanakma01', 22000000.0),
#  ('rodrial01', 18109829.636363637),
#  ('howarry01', 15525500.0),
#  ('teixema01', 15305357.142857144),
#  ('sabatcc01', 14576190.4),
#  ('jeterde01', 13927268.05263158),
#  ('fieldpr01', 13901318.181818182),
#  ('cabremi01', 13457901.642857144),
#  ('mauerjo01', 13232692.307692308),
#  ('cespeyo01', 13165609.2),
#  ('verlaju01', 12974090.909090908),
#  ('pujolal01', 12752527.25),
#  ('kurodhi01', 12580817.57142857),
#  ('hamelco01', 12540000.0),
#  ('hernafe02', 12529844.181818182),
#  ('linceti01', 12444375.0),
#  ('hollima01', 12040131.083333334),
#  ('greinza01', 12025169.166666666),
#  ('canoro01', 11806527.272727273),
#  ('priceda01', 11693042.285714285),
#  ('zambrca01', 11495000.0),
#  ('beltrca01', 11432376.777777778),
#  ('soriaal01', 11425714.285714285),
#  ('kershcl01', 11301875.0),
#  ('hamiljo03', 10969057.9),
#  ('ramirma02', 10885672.05263158),
# ...

# %% [markdown]
# The player with the ID 'tanakma01' has the greatest average salary in our dataset of \$220,00,000.

# %% [markdown]
# ## Question 5

# %% [markdown]
# Now create your own query about a topic that you are interested in. Use at least one of the aggregation functions, such as min, max, count, or sum. Be sure to use group by and display the results in order with order by
#
# My question: which team has the highest average home runs over the years?

# %%
# %%sql
# SELECT
#     name,
#     AVG(HR) as avg_hr
# FROM
#     teams
# GROUP BY
#     name
# ORDER BY
#     avg_hr DESC
# LIMIT 1;
# Out:
#  * sqlite:////anvil/projects/tdm/data/lahman/lahman.db
# Done.
# [('Colorado Rockies', 178.13333333333333)]

# %% [markdown]
# The Colorado Rockies have the highest average home runs over the years.

# %% [markdown]
# ## Pledge
#
# By submitting this work I hereby pledge that this is my own, personal work. I've acknowledged in the designated place at the top of this file all sources that I used to complete said work, including but not limited to: online resources, books, and electronic communications. I've noted all collaboration with fellow students and/or TA's. I did not copy or plagiarize another's work.
#
# > As a Boilermaker pursuing academic excellence, I pledge to be honest and true in all that I do. Accountable together – We are Purdue.
